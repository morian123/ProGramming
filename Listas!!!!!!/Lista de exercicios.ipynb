# %% [markdown]
# ><a href="https://www.ufes.br/">
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Bras%C3%A3o_Ufes.svg/1200px-Bras%C3%A3o_Ufes.svg.png" alt="Drawing" width="85"></a>
# <img width="80">
# <a href="https://peteletrica.ufes.br/petcode/">
# <img src="https://peteletrica.ufes.br/wp-content/uploads/2023/03/cropped-cropped-cropped-WhatsApp_Image_2023-03-21_at_15.50.15-removebg-preview-1-1.png" alt="Drawing" width="280"></a>  <center>

# %% [markdown]
# # **Lista de exercícios aula 1**

# %% [markdown]
# # Exercício 01

# %% [markdown]
# > A fórmula para calcular a área de uma circunferência é: area = π * raio². Considerando para este problema que π = 3.14159:
# >
# - Efetue o cálculo da área, elevando o valor de raio ao quadrado e multiplicando por π.
# >
# > **Entrada**
# >
# > A entrada contém um valor de ponto flutuante (float), no caso, a variável raio.
# >
# > **Saída**
# >
# > Apresentar a mensagem "A=" seguido pelo valor da variável area, conforme exemplo abaixo, com 4 casas após o ponto decimal. Utilize variáveis float. Como todos os problemas, não esqueça de imprimir o fim de linha após o resultado, caso contrário, você receberá "Presentation Error".

# %%
# Escreva a solução aqui!
# Dica: para limitar o número de casas decimais na impressão do número utilize
# a notação {:.nf}, onde n = número de casas decimais que deseja representar.

raio = float(input("digite o valor do raio aki meu nobre"))

Pi = 3.14159

A = Pi * (raio**2)

print(f"o valor da area é:", A)
# Out:
# o valor da area é: 201.06176

# %% [markdown]
# # Exercício 2

# %% [markdown]
# > Faça um programa que lê dois números **inteiros** (x e y) do teclado e verifica qual é maior, ou se os dois são iguais.

# %%
# Escreva a solução aqui!
# Dica: utilize os comandos abaixo para converter os números em inteiros
# assim que o usuário os fornecer na entrada:

# x = int(input())
# y = int(input())

# Resto do código aqui

x = int(input("digite o valor de X"))
y = int(input("digite o valor de y"))

if x > y:
    print("o valor de x é:", x, "sendo ele maior que y que é", y)
else: 
    print("o valor de y é", y, "sendo ele maior que x, tendo o valor de", x)
# Out:
# o valor de y é 9 sendo ele maior que x, tendo o valor de 1

# %% [markdown]
# # Exercício 3

# %% [markdown]
# > Leia 3 valores de ponto flutuante e efetue o cálculo das raízes da equação de Bhaskara. Se não for possível calcular as raízes, mostre a mensagem correspondente “Impossivel calcular”, caso haja uma divisão por 0 ou raiz de numero negativo.
# >
# > **Entrada**
# >
# > Leia três valores de ponto flutuante (float) A, B e C.
# >
# > **Saída**
# >
# > Se não houver possibilidade de calcular as raízes, apresente a mensagem "Impossivel calcular". Caso contrário, imprima o resultado das raízes com 5 dígitos após o ponto, com uma mensagem correspondente conforme exemplo abaixo. Imprima sempre o final de linha após cada mensagem.

# %%
# Escreva a solução aqui!
# Dica: utilize o comando .split() para separar os itens do input() e depois os
# converta para float. Exemplo abaixo:

# A, B, C = input().split()
# A = float(A)
# B = float(B)
# C = float(C)

# Resto do código aqui

A, B, C = input("igite o valor de A, B e C").split()
A = float(A)
B = float(B)
C = float(C)

delta = (B**2) - 4 * A * C

print("esse é o valor de delta", delta)

if delta == 0:
    print("delta na existe")

else:
    x1 = (-B + (delta**1/2)) / 2 * A
    
    x2 = (-B - (delta**1/2)) / 2 * A

print("o valor de A, B e C sao:", A, B, C)

print("o valor de x1 é:", x1, "e o valor de x2 é:", x2)
# Out:
# esse é o valor de delta -239.0
# o valor de A, B e C sao: 8.0 7.0 9.0
# o valor de x1 é: -506.0 e o valor de x2 é: 450.0

# %% [markdown]
# # Exercício 4

# %% [markdown]
# > Suponha que você está desenvolvendo um jogo 2D de tiro ao alvo e você deseja verificar se um tiro acertou o alvo. Assuma que o tiro e o alvo são círculos e são conhecidas suas posições e raios.
# >
# > O programa deve receber as coordenadas dos centros dos círculos (x,y) e seus raios (r) na mesma linha, respectivamente. Exemplo de entrada:
# >
# - 10.5  12  3 (x,y e r do alvo)
# -  14.7  13.2  8 (x,y e r do tiro)
#
#
#
# > <a href="https://peteletrica.ufes.br/petcode/">
# <img src="https://peteletrica.ufes.br/wp-content/uploads/2023/09/questao.png" alt="Drawing" width=""></a>  <center>

# %%
# Escreva a solução aqui!
# Dica: utilize o comando .split() para separar os itens do input() e depois os
# converta para float. Exemplo abaixo:
# Dica 2: para que haja uma colisão, a distância entre os centros dos círculos
# (alvo e tiro) deve ser menor que os raios somados!


x_alvo, y_alvo, raio_alvo = input("digite os valores do alvo X, Y e seu raio: ").split()
x_alvo = float(x_alvo)
y_alvo = float(y_alvo)
raio_alvo = float(raio_alvo)

x_tiro, y_tiro, raio_tiro = input("digite onde foi o tiro x e y, e onde foi o raio do tiro: ").split()
x_tiro = float(x_tiro)
y_tiro = float(y_tiro)
raio_tiro = float(raio_tiro)

distancia = ((x_alvo - x_tiro) ** 2 + (y_alvo - y_tiro) ** 2) ** 0.5

if x_alvo != x_tiro: 
  print("o tiro nao teve a colisao pois o alvo: ", x_alvo, "e o tiro: ", x_tiro, "não estao no mesmo ponto")
  print("a distancia do alvo ao tiro foi: ", distancia)

elif y_alvo != y_tiro:
  print("o tiro nao teve a colisao pois o alvo: ", y_alvo, "e o tiro: ", y_tiro, "não estao no mesmo ponto")
  print("a distancia do alvo ao tiro foi: ", distancia)

elif raio_alvo != raio_tiro:
  print("o tiro nao teve a colisao pois o raio do alvo:", raio_alvo,"e do tiro: ", raio_tiro,"não batem")
  print("a distancia do alvo ao tiro foi: ", distancia)
  
else:
  print("o tiro teve uma colisao")
  print("a distancia do alvo ao tiro foi: ", distancia)
  


# Resto do código aqui


#receber coordenadads de onde veio os tiros x e y e seu raio

# %% [markdown]
# # Desafio!!!

# %% [markdown]
# > Considere um jogo que tenha um tanque com
# um canhão que se move ao em relação ao eixo
# vertical. Faça um programa que leia a posição
# do tanque (ty, tx) e seu tamanho (h, w), além
# do ângulo do canhão 𝜃 e seu tamanho t.
# Mostre na tela a posição da base do canhão
# (by, bx) assumindo que ela está na metade da
# largura do tanque e a posição da ponta do
# canhão (cy,cx).
#
# > <a href="https://peteletrica.ufes.br/petcode/">
# <img src="https://peteletrica.ufes.br/wp-content/uploads/2023/09/questao2.png" alt="Drawing" width=""></a>  <center>

# %%
# Escreva a solução aqui!
# Dica: utilize relações trigonométricas com a biblioteca math
# https://docs.python.org/3/library/math.html#trigonometric-functions

# Resto do código aqui
# .
# .
# .
# cy = by - (t*math.cos(ang))
# cx = bx + (t*math.sin(ang))


#ler a posição do ty e tx
#ler o seu tamanho pelo H e W
#ler o angulo 0 do canhao e o seu tamanho pelo T
#ler a posição do canhao na base by e bx
#ler que ele esta na metade da largura do tanque e a posição na ponta do canhão


#pontilhado branco= maximo do canhão
#H=altura
#W=largura
#ty e tx= posição do canhão
#0=angulo do canhao
#T=tamanho do canhao
#by e bx=posição do canhão na base
#calcular usando trigonometria, mas to so na preguiça
# Out:
# As saídas do seu código aparecerão aqui.
